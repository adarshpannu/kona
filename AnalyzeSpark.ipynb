# %% [markdown]
# # Analyze

# %%
# Essential imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from datetime import datetime
from functools import reduce

import yfinance as yf

import pyarrow as pa
import pyarrow.parquet as pq

# Ignore DeprecationWarnings
import warnings
warnings.simplefilter('ignore', DeprecationWarning)

# Enable multiple outputs from each cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Make columns wider
pd.set_option('max_colwidth',1024*1024)

# %matplotlib inline

# %%
DATADIR = "/Users/adarshrp/Projects/Trading"
dfG250 = pd.read_csv(DATADIR + "/MarketSmith/Extracts/Growth250.csv")
dfUniverse = pd.read_csv(DATADIR + "/MarketSmith/Extracts/MarketSmithUniverseCurated.csv")

# %%
def rename_columns(oldColumns):
    newColumns = oldColumns
    newColumns = [re.sub("/", "", col) for col in newColumns]
    newColumns = [re.sub("[\-\(\) ]", "_", col.replace("%", "Perc").replace("$", "Dollar")) for col in newColumns]
    newColumns = [re.sub("[_]+", "_", col) for col in newColumns]
    newColumns = [re.sub("[_]$", "", col) for col in newColumns]
    return newColumns

# %%
import re

universe = spark.read.option("header", True).option("inferSchema", True).csv(DATADIR + "/MarketSmith/Extracts/MarketSmithUniverseCurated.csv")
#universe.printSchema()

#oldColumns = universe.columns
#newColumns = rename_columns(oldColumns)

#universe = reduce(lambda data, idx: data.withColumnRenamed(oldColumns[idx], newColumns[idx]), range(len(oldColumns)), universe)
universe.printSchema()

universe.createOrReplaceTempView("universe")
# Out:
# root
#  |-- Order: integer (nullable = true)
#  |-- Symbol: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Industry_Name: string (nullable = true)
#  |-- Ind_Group_Rank: integer (nullable = true)
#  |-- Sector: string (nullable = true)
#  |-- Shares_1000s: integer (nullable = true)
#  |-- Shares_in_Float_1000s: integer (nullable = true)
#  |-- Market_Cap_mil: double (nullable = true)
#  |-- Funds_Perc: double (nullable = true)
#  |-- Funds_Perc_Increase: double (nullable = true)
#  |-- Mgmt_Perc: double (nullable = true)
#  |-- Number_of_Funds: double (nullable = true)
#  |-- Inst_Ownership_Lss_Median: double (nullable = true)
#  |-- Sponsor_Rating: string (nullable = true)
#  |-- Enterprise_Val_mil: double (nullable = true)
#  |-- EPS_Rating: double (nullable = true)
#  |-- RS_Rating: double (nullable = true)
#  |-- SMR_Rating: string (nullable = true)
#  |-- AD_Rating: string (nullable = true)
#  |-- Comp_Rating: double (nullable = true)
#  |-- Ind_Group_RS: string (nullable = true)
#  |-- EPS_Lst_Rptd: string (nullable = true)
#  |-- EPS_Due_Date: string (nullable = true)
#  |-- EPS_Perc_Chg_Last_Qtr: double (nullable = true)
#  |-- EG0: double (nullable = true)
#  |-- EPS_Perc_Chg_1_Q_Ago: double (nullable = true)
#  |-- EG1: double (nullable = true)
#  |-- EPS_Perc_Chg_2_Q_Ago: double (nullable = true)
#  |-- EG2: double (nullable = true)
#  |-- EPS_Perc_Chg_3_Q_Ago: double (nullable = true)
#  |-- EG3: double (nullable = true)
#  |-- EPS_Accel_3_Qtrs: integer (nullable = true)
#  |-- EPS_Trailing_4_Qtrs: double (nullable = true)
#  |-- EPS_Perc_Growth_5_Yr_Pct_Rnk: double (nullable = true)
#  |-- EPS_Est_Next_Yr_Perc: double (nullable = true)
#  |-- EPS_Est_Cur_Yr_Perc: double (nullable = true)
#  |-- EPS_Est_Cur_Qtr_Perc: double (nullable = true)
#  |-- EPS_Surprise: double (nullable = true)
#  |-- Sustainable_Growth_Perc: double (nullable = true)
#  |-- Earnings_Stability: double (nullable = true)
#  |-- Avg_EPS_Perc_Chg_2Q: double (nullable = true)
#  |-- Avg_EPS_Perc_Chg_3Q: double (nullable = true)
#  |-- Avg_EPS_Perc_Chg_4Q: double (nullable = true)
#  |-- Avg_EPS_Perc_Chg_5Q: double (nullable = true)
#  |-- Avg_EPS_Perc_Chg_6Q: double (nullable = true)
#  |-- EPS_Perc_Chg_Lst_Yr: double (nullable = true)
#  |-- EPS_Perc_Chg_1_Yr_Ago: double (nullable = true)
#  |-- EPS_Perc_Growth_1_Yr: double (nullable = true)
#  |-- EPS_Perc_Growth_3_Yr: double (nullable = true)
#  |-- EPS_Perc_Growth_5_Yr: double (nullable = true)
#  |-- Fiscal_EPS_Lst_Yr: double (nullable = true)
#  |-- Fiscal_EPS_1_Yr_Ago: double (nullable = true)
#  |-- Fiscal_EPS_2_Yrs_Ago: double (nullable = true)
#  |-- Fiscal_EPS_3_Yrs_Ago: double (nullable = true)
#  |-- Fiscal_EPS_4_Yrs_Ago: double (nullable = true)
#  |-- Fiscal_EPS_5_Yrs_Ago: double (nullable = true)
#  |-- Fiscal_EPS_6_Yrs_Ago: double (nullable = true)
#  |-- SG0: double (nullable = true)
#  |-- Avg_Sales_Perc_Chg_2Q: double (nullable = true)
#  |-- Avg_Sales_Perc_Chg_3Q: double (nullable = true)
#  |-- Avg_Sales_Perc_Chg_4Q: double (nullable = true)
#  |-- Avg_Sales_Perc_Chg_5Q: double (nullable = true)
#  |-- Avg_Sales_Perc_Chg_6Q: double (nullable = true)
#  |-- Sales_Perc_Chg_Lst_Yr: double (nullable = true)
#  |-- Sales_Accel_2_Qtrs: integer (nullable = true)
#  |-- Sales_Accel_3_Qtrs: integer (nullable = true)
#  |-- Sales_Growth_3_Yr: double (nullable = true)
#  |-- Sales_Growth_5_Yr: double (nullable = true)
#  |-- Annual_Sales_mil: double (nullable = true)
#  |-- Current_Price: double (nullable = true)
#  |-- 50_Day_Avg_Vol_1000s: double (nullable = true)
#  |-- 50_Day_Avg_Dollar_Vol_1000s: integer (nullable = true)
#  |-- Volume_1000s: integer (nullable = true)
#  |-- Timeliness_Rating: string (nullable = true)
#  |-- Avg_True_Range: double (nullable = true)
#  |-- Beta: double (nullable = true)
#  |-- Alpha: double (nullable = true)
#  |-- RS_6_Month_Rating: double (nullable = true)
#  |-- RS_3_Month_Rating: double (nullable = true)
#  |-- RS_Line_New_Low: double (nullable = true)
#  |-- RS_Line_New_High: double (nullable = true)
#  |-- Perc_Off_High: double (nullable = true)
#  |-- Yield_Perc: double (nullable = true)
#  |-- Pre_tax_Margins: double (nullable = true)
#  |-- AT_Margin_Accel: integer (nullable = true)
#  |-- PE_Lss_5_Yr_Avg: integer (nullable = true)
#  |-- LT_Debt_to_Working_Cap: double (nullable = true)
#  |-- PE_Ratio_Rank_in_Grp: double (nullable = true)
#  |-- PE_Percent_Rank: double (nullable = true)
#  |-- Est_PE: double (nullable = true)
#  |-- PE_vs_S&P_500_PE_Perc: double (nullable = true)
#  |-- AT_Margin: double (nullable = true)
#  |-- Avg_AT_Margin_2Q: double (nullable = true)
#  |-- Avg_AT_Margin_3Q: double (nullable = true)
#  |-- Avg_AT_Margin_4Q: double (nullable = true)
#  |-- Avg_AT_Margin_5Q: double (nullable = true)
#  |-- Avg_AT_Margin_6Q: double (nullable = true)
#  |-- PE: double (nullable = true)
#  |-- ROE: double (nullable = true)
#  |-- ROE_5_Yr_Avg: double (nullable = true)
#  |-- Debt_Perc: double (nullable = true)
#  |-- Current_Ratio: double (nullable = true)
#  |-- Price_to_Sales: double (nullable = true)
#  |-- Price_to_Book: double (nullable = true)
#  |-- Price_to_CF: double (nullable = true)
#  |-- Exchange: string (nullable = true)
#  |-- ADR: integer (nullable = true)
#  |-- IPO_Date: string (nullable = true)
#  |-- Company_Description: string (nullable = true)
#  |-- Incorp_Date: double (nullable = true)
#  |-- IBD_Article_2_Yrs: integer (nullable = true)
#  |-- EG4: double (nullable = true)
#  |-- EG5: double (nullable = true)
#  |-- SG1: double (nullable = true)
#  |-- SG2: double (nullable = true)
#  |-- SG3: double (nullable = true)
#  |-- SG4: double (nullable = true)
#  |-- SG5: double (nullable = true)
#  |-- Dollar_Volume_mil: double (nullable = true)
#  |-- Dollar_Volume_Sales: double (nullable = true)

# %%
#parquetFile = spark.read.parquet("Data/ADBE-2001-01-01-2021-12-31.parquet")
prices = spark.read.parquet(DATADIR + "/Data/Enriched")

prices.createOrReplaceTempView("prices")

# %%
prices.printSchema()
# Out:
# root
#  |-- index: long (nullable = true)
#  |-- Ticker: string (nullable = true)
#  |-- Date: date (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Adj Close: double (nullable = true)
#  |-- Volume: double (nullable = true)
#  |-- SMA20: double (nullable = true)
#  |-- SMA50: double (nullable = true)
#  |-- SMA150: double (nullable = true)
#  |-- SMA200: double (nullable = true)
#  |-- HIGH52WK: double (nullable = true)
#  |-- LOW52WK: double (nullable = true)
#  |-- Volume14MA: double (nullable = true)
#  |-- Strength21: double (nullable = true)
#  |-- Strength42: double (nullable = true)
#  |-- Strength63: double (nullable = true)
#  |-- Strength: double (nullable = true)
#  |-- PrevClose: double (nullable = true)
#  |-- ATR: double (nullable = true)

# %%
spark.sql("""
  SELECT count(*) from prices
""").show(200)
# Out:
# +--------+
# |count(1)|
# +--------+
# | 2891621|
# +--------+

# %%
# Filter stocks based on following criteria:
# - Minervini trend template
# - Computers related
# - Earnings > 20, Sales > 15
# Ordered by 21-day relative strength
q = spark.sql("""
    SELECT Ticker, Date
    FROM prices P
    where (Ticker = 'ADBE' or Ticker = 'IBM')
""")
q.show(200)


#for ticker in q.toPandas().Ticker:
#    print(ticker)
# Out:
# +------+----------+
# |Ticker|      Date|
# +------+----------+
# |  ADBE|2018-01-02|
# |  ADBE|2018-01-03|
# |  ADBE|2018-01-04|
# |  ADBE|2018-01-05|
# |  ADBE|2018-01-08|
# |  ADBE|2018-01-09|
# |  ADBE|2018-01-10|
# |  ADBE|2018-01-11|
# |  ADBE|2018-01-12|
# |  ADBE|2018-01-16|
# |  ADBE|2018-01-17|
# |  ADBE|2018-01-18|
# |  ADBE|2018-01-19|
# |  ADBE|2018-01-22|
# |  ADBE|2018-01-23|
# |  ADBE|2018-01-24|
# |  ADBE|2018-01-25|
# |  ADBE|2018-01-26|
# |  ADBE|2018-01-29|
# |  ADBE|2018-01-30|
# |  ADBE|2018-01-31|
# |  ADBE|2018-02-01|
# |  ADBE|2018-02-02|
# |  ADBE|2018-02-05|
# |  ADBE|2018-02-06|
# |  ADBE|2018-02-07|
# |  ADBE|2018-02-08|
# |  ADBE|2018-02-09|
# |  ADBE|2018-02-12|
# |  ADBE|2018-02-13|
# |  ADBE|2018-02-14|
# |  ADBE|2018-02-15|
# |  ADBE|2018-02-16|
# |  ADBE|2018-02-20|
# |  ADBE|2018-02-21|
# |  ADBE|2018-02-22|
# |  ADBE|2018-02-23|
# |  ADBE|2018-02-26|
# |  ADBE|2018-02-27|
# |  ADBE|2018-02-28|
# |  ADBE|2018-03-01|
# |  ADBE|2018-03-02|
# |  ADBE|2018-03-05|
# |  ADBE|2018-03-06|
# |  ADBE|2018-03-07|
# |  ADBE|2018-03-08|
# |  ADBE|2018-03-09|
# |  ADBE|2018-03-12|
# |  ADBE|2018-03-13|
# |  ADBE|2018-03-14|
# |  ADBE|2018-03-15|
# |  ADBE|2018-03-16|
# |  ADBE|2018-03-19|
# |  ADBE|2018-03-20|
# |  ADBE|2018-03-21|
# |  ADBE|2018-03-22|
# |  ADBE|2018-03-23|
# |  ADBE|2018-03-26|
# |  ADBE|2018-03-27|
# |  ADBE|2018-03-28|
# |  ADBE|2018-03-29|
# |  ADBE|2018-04-02|
# |  ADBE|2018-04-03|
# |  ADBE|2018-04-04|
# |  ADBE|2018-04-05|
# |  ADBE|2018-04-06|
# |  ADBE|2018-04-09|
# |  ADBE|2018-04-10|
# |  ADBE|2018-04-11|
# |  ADBE|2018-04-12|
# |  ADBE|2018-04-13|
# |  ADBE|2018-04-16|
# |  ADBE|2018-04-17|
# |  ADBE|2018-04-18|
# |  ADBE|2018-04-19|
# |  ADBE|2018-04-20|
# |  ADBE|2018-04-23|
# |  ADBE|2018-04-24|
# |  ADBE|2018-04-25|
# |  ADBE|2018-04-26|
# |  ADBE|2018-04-27|
# |  ADBE|2018-04-30|
# |  ADBE|2018-05-01|
# |  ADBE|2018-05-02|
# |  ADBE|2018-05-03|
# |  ADBE|2018-05-04|
# |  ADBE|2018-05-07|
# |  ADBE|2018-05-08|
# |  ADBE|2018-05-09|
# |  ADBE|2018-05-10|
# |  ADBE|2018-05-11|
# |  ADBE|2018-05-14|
# |  ADBE|2018-05-15|
# |  ADBE|2018-05-16|
# |  ADBE|2018-05-17|
# |  ADBE|2018-05-18|
# |  ADBE|2018-05-21|
# |  ADBE|2018-05-22|
# |  ADBE|2018-05-23|
# |  ADBE|2018-05-24|
# |  ADBE|2018-05-25|
# |  ADBE|2018-05-29|
# |  ADBE|2018-05-30|
# |  ADBE|2018-05-31|
# |  ADBE|2018-06-01|
# |  ADBE|2018-06-04|
# |  ADBE|2018-06-05|
# |  ADBE|2018-06-06|
# |  ADBE|2018-06-07|
# |  ADBE|2018-06-08|
# |  ADBE|2018-06-11|
# |  ADBE|2018-06-12|
# |  ADBE|2018-06-13|
# |  ADBE|2018-06-14|
# |  ADBE|2018-06-15|
# |  ADBE|2018-06-18|
# |  ADBE|2018-06-19|
# |  ADBE|2018-06-20|
# |  ADBE|2018-06-21|
# |  ADBE|2018-06-22|
# |  ADBE|2018-06-25|
# |  ADBE|2018-06-26|
# |  ADBE|2018-06-27|
# |  ADBE|2018-06-28|
# |  ADBE|2018-06-29|
# |  ADBE|2018-07-02|
# |  ADBE|2018-07-03|
# |  ADBE|2018-07-05|
# |  ADBE|2018-07-06|
# |  ADBE|2018-07-09|
# |  ADBE|2018-07-10|
# |  ADBE|2018-07-11|
# |  ADBE|2018-07-12|
# |  ADBE|2018-07-13|
# |  ADBE|2018-07-16|
# |  ADBE|2018-07-17|
# |  ADBE|2018-07-18|
# |  ADBE|2018-07-19|
# |  ADBE|2018-07-20|
# |  ADBE|2018-07-23|
# |  ADBE|2018-07-24|
# |  ADBE|2018-07-25|
# |  ADBE|2018-07-26|
# |  ADBE|2018-07-27|
# |  ADBE|2018-07-30|
# |  ADBE|2018-07-31|
# |  ADBE|2018-08-01|
# |  ADBE|2018-08-02|
# |  ADBE|2018-08-03|
# |  ADBE|2018-08-06|
# |  ADBE|2018-08-07|
# |  ADBE|2018-08-08|
# |  ADBE|2018-08-09|
# |  ADBE|2018-08-10|
# |  ADBE|2018-08-13|
# |  ADBE|2018-08-14|
# |  ADBE|2018-08-15|
# |  ADBE|2018-08-16|
# |  ADBE|2018-08-17|
# |  ADBE|2018-08-20|
# |  ADBE|2018-08-21|
# |  ADBE|2018-08-22|
# |  ADBE|2018-08-23|
# |  ADBE|2018-08-24|
# |  ADBE|2018-08-27|
# |  ADBE|2018-08-28|
# |  ADBE|2018-08-29|
# |  ADBE|2018-08-30|
# |  ADBE|2018-08-31|
# |  ADBE|2018-09-04|
# |  ADBE|2018-09-05|
# |  ADBE|2018-09-06|
# |  ADBE|2018-09-07|
# |  ADBE|2018-09-10|
# |  ADBE|2018-09-11|
# |  ADBE|2018-09-12|
# |  ADBE|2018-09-13|
# |  ADBE|2018-09-14|
# |  ADBE|2018-09-17|
# |  ADBE|2018-09-18|
# |  ADBE|2018-09-19|
# |  ADBE|2018-09-20|
# |  ADBE|2018-09-21|
# |  ADBE|2018-09-24|
# |  ADBE|2018-09-25|
# |  ADBE|2018-09-26|
# |  ADBE|2018-09-27|
# |  ADBE|2018-09-28|
# |  ADBE|2018-10-01|
# |  ADBE|2018-10-02|
# |  ADBE|2018-10-03|
# |  ADBE|2018-10-04|
# |  ADBE|2018-10-05|
# |  ADBE|2018-10-08|
# |  ADBE|2018-10-09|
# |  ADBE|2018-10-10|
# |  ADBE|2018-10-11|
# |  ADBE|2018-10-12|
# |  ADBE|2018-10-15|
# |  ADBE|2018-10-16|
# +------+----------+
# only showing top 200 rows

# %%
# Filter stocks based on following criteria:
# - Minervini trend template
# - Computers related
# - Earnings > 20, Sales > 15
# Ordered by 21-day relative strength
q = spark.sql("""
WITH RSRATING AS (
    SELECT Ticker, Date, 
       Strength, 
       int(percent_rank(Strength) over (partition by Date order by Strength asc) * 100) RS
    FROM prices P
  ),
Q AS (
SELECT P.Ticker, P.Date, 
       --Open, Close, PrevClose, ATR,
       SMA50, SMA200, 
       Volume, Volume14MA,
       R.Strength, R.RS
FROM prices P, universe U, RSRating R 
where
     P.Ticker = U.Symbol and P.Ticker = R.Ticker and P.Date = R.Date
  and P.Date = '2021-10-04' 
  and (
      EG0 >= 20  --After 3Q 2020
  and SG0 >= 15

  and EG1 >= 20 
  and SG1 >= 15

  and close >= 25
  and close >= SMA50*0.95
  and sma50 >= sma200
  --and close >= 0.75 * HIGH52WK
  --and close >= 1.25 * LOW52WK
  --and Volume14MA > 250000
  and Volume14MA * SMA50 > 25e6)
  ORDER BY RS Desc 
)
SELECT count(*) from Q

--((Close - Open) >= ATR or (Close - PrevClose) >= ATR)
--and Volume >= Volume14MA
""")
q.show(200)


#for ticker in q.toPandas().Ticker:
#    print(ticker)
# Out:
# +--------+
# |count(1)|
# +--------+
# |     146|
# +--------+

# %%
dfUniverse[dfUniverse.Symbol == 'ORLY'].to_dict(orient='list')
# Out:
# {'Order': [2272],
#  'Symbol': ['ORLY'],
#  'Name': ['O Reilly Automotive Inc'],
#  'Industry_Name': ['Retail/Whlsle-Auto Parts'],
#  'Ind_Group_Rank': [37],
#  'Sector': ['RETAIL'],
#  'Shares_1000s': [68951],
#  'Shares_in_Float_1000s': [66882],
#  'Market_Cap_mil': [41885.7],
#  'Funds_Perc': [46.0],
#  'Funds_Perc_Increase': [6.5],
#  'Mgmt_Perc': [2.0],
#  'Number_of_Funds': [1954.0],
#  'Inst_Ownership_Lss_Median': [0.0],
#  'Sponsor_Rating': ['B'],
#  'Enterprise_Val_mil': [45326.8],
#  'EPS_Rating': [92.0],
#  'RS_Rating': [81.0],
#  'SMR_Rating': ['A'],
#  'AD_Rating': ['D'],
#  'Comp_Rating': [92.0],
#  'Ind_Group_RS': ['A-'],
#  'EPS_Lst_Rptd': ['2021-07-28'],
#  'EPS_Due_Date': ['2021-10-28'],
#  'EPS_Perc_Chg_Last_Qtr': [17.0],
#  'EG0': [17.0],
#  'EPS_Perc_Chg_1_Q_Ago': [78.0],
#  'EG1': [78.0],
#  'EPS_Perc_Chg_2_Q_Ago': [27.0],
#  'EG2': [27.0],
#  'EPS_Perc_Chg_3_Q_Ago': [39.0],
#  'EG3': [39.0],
#  'EPS_Accel_3_Qtrs': [0],
#  'EPS_Trailing_4_Qtrs': [27.86],
#  'EPS_Perc_Growth_5_Yr_Pct_Rnk': [79.0],
#  'EPS_Est_Next_Yr_Perc': [6.0],
#  'EPS_Est_Cur_Yr_Perc': [18.0],
#  'EPS_Est_Cur_Qtr_Perc': [-1.0],
#  'EPS_Surprise': [8.6],
#  'Sustainable_Growth_Perc': [652.0],
#  'Earnings_Stability': [5.0],
#  'Avg_EPS_Perc_Chg_2Q': [47.6],
#  'Avg_EPS_Perc_Chg_3Q': [40.7],
#  'Avg_EPS_Perc_Chg_4Q': [40.3],
#  'Avg_EPS_Perc_Chg_5Q': [43.8],
#  'Avg_EPS_Perc_Chg_6Q': [36.1],
#  'EPS_Perc_Chg_Lst_Yr': [32.0],
#  'EPS_Perc_Chg_1_Yr_Ago': [11.0],
#  'EPS_Perc_Growth_1_Yr': [38.0],
#  'EPS_Perc_Growth_3_Yr': [24.0],
#  'EPS_Perc_Growth_5_Yr': [22.0],
#  'Fiscal_EPS_Lst_Yr': [23.53],
#  'Fiscal_EPS_1_Yr_Ago': [17.88],
#  'Fiscal_EPS_2_Yrs_Ago': [16.1],
#  'Fiscal_EPS_3_Yrs_Ago': [12.02],
#  'Fiscal_EPS_4_Yrs_Ago': [10.73],
#  'Fiscal_EPS_5_Yrs_Ago': [9.06],
#  'Fiscal_EPS_6_Yrs_Ago': [7.34],
#  'SG0': [12.0],
#  'Avg_Sales_Perc_Chg_2Q': [18.4],
#  'Avg_Sales_Perc_Chg_3Q': [16.9],
#  'Avg_Sales_Perc_Chg_4Q': [17.8],
#  'Avg_Sales_Perc_Chg_5Q': [18.1],
#  'Avg_Sales_Perc_Chg_6Q': [15.5],
#  'Sales_Perc_Chg_Lst_Yr': [14.0],
#  'Sales_Accel_2_Qtrs': [0],
#  'Sales_Accel_3_Qtrs': [0],
#  'Sales_Growth_3_Yr': [11.0],
#  'Sales_Growth_5_Yr': [8.0],
#  'Annual_Sales_mil': [11604.5],
#  'Current_Price': [608.79],
#  '50_Day_Avg_Vol_1000s': [404.0],
#  '50_Day_Avg_Dollar_Vol_1000s': [247173],
#  'Volume_1000s': [189],
#  'Timeliness_Rating': ['C'],
#  'Avg_True_Range': [10.46],
#  'Beta': [0.63],
#  'Alpha': [0.05],
#  'RS_6_Month_Rating': [87.0],
#  'RS_3_Month_Rating': [81.0],
#  'RS_Line_New_Low': [0.0],
#  'RS_Line_New_High': [0.0],
#  'Perc_Off_High': [-3.27],
#  'Yield_Perc': [0.0],
#  'Pre_tax_Margins': [19.5],
#  'AT_Margin_Accel': [1],
#  'PE_Lss_5_Yr_Avg': [1],
#  'LT_Debt_to_Working_Cap': [-3.7],
#  'PE_Ratio_Rank_in_Grp': [29.0],
#  'PE_Percent_Rank': [58.0],
#  'Est_PE': [22.0],
#  'PE_vs_S&P_500_PE_Perc': [91.39],
#  'AT_Margin': [16.9],
#  'Avg_AT_Margin_2Q': [16.6],
#  'Avg_AT_Margin_3Q': [15.7],
#  'Avg_AT_Margin_4Q': [15.9],
#  'Avg_AT_Margin_5Q': [16.1],
#  'Avg_AT_Margin_6Q': [15.5],
#  'PE': [22.0],
#  'ROE': [651.9],
#  'ROE_5_Yr_Avg': [610.9],
#  'Debt_Perc': [2939.7],
#  'Current_Ratio': [0.82],
#  'Price_to_Sales': [3.33],
#  'Price_to_Book': [301.88],
#  'Price_to_CF': [14.93],
#  'Exchange': ['NASDAQ'],
#  'ADR': [0],
#  'IPO_Date': ['1993-04-22'],
#  'Company_Description': ['OPERATES 5,594 AUTOMOTIVE PARTS STORES IN 47 STATES WITH PLA NS TO OPEN ABOUT 165-175 STORES IN 2021.'],
#  'Incorp_Date': [1957.0],
#  'IBD_Article_2_Yrs': [0],
#  'EG4': [57.8],
#  'EG5': [-2.4],
#  'SG1': [24.8],
#  'SG2': [13.9],
#  'SG3': [20.5],
#  'SG4': [19.3],
#  'SG5': [2.5],
#  'Dollar_Volume_mil': [115.06],
#  'Dollar_Volume_Sales': [0.01]}

# %%
df = spark.sql("""
  WITH RSRATING AS (
    SELECT Ticker, Industry_name, Date, Close,
           Strength21, int(percent_rank(Strength21) over (partition by Date order by Strength21 asc) * 100) RS21,
           Strength42, int(percent_rank(Strength42) over (partition by Date order by Strength42 asc) * 100) RS42,
           Strength63, int(percent_rank(Strength63) over (partition by Date order by Strength63 asc) * 100) RS63,
           Strength, int(percent_rank(Strength) over (partition by Date order by Strength asc) * 100)     RS
    FROM prices P, universe U 
    where
         P.Ticker = U.Symbol)
  select * from RSRATING
    where 
      Date = '2020-04-06'
      and Industry_name like "Computer%"
      --and Ticker in ('ADBE')
    order by Date asc, RS21 desc
""").show(30)

#df
#df.RSRating.rolling(14).mean().plot()
#df.RSRating.tail(23)
# Out:
# +------+--------------------+----------+------+----------+----+----------+----+----------+----+--------+---+
# |Ticker|       Industry_name|      Date| Close|Strength21|RS21|Strength42|RS42|Strength63|RS63|Strength| RS|
# +------+--------------------+----------+------+----------+----+----------+----+----------+----+--------+---+
# |    ZS|Computer Sftwr-Se...|2020-04-06| 63.31|     28.18|  99|     22.19|  99|     22.55|  99|    12.9| 95|
# |  NTGR| Computer-Networking|2020-04-06|  22.6|     20.99|  99|     10.83|  98|      4.48|  96|  -20.24| 67|
# |  AUDC|Computer Sftwr-En...|2020-04-06| 26.39|     21.11|  99|     19.43|  99|     16.96|  98|   38.72| 98|
# |  CRWD|Computer Sftwr-Se...|2020-04-06| 59.07|     13.68|  98|      8.25|  97|      6.95|  97|    null|  0|
# |  LOGI|Computer-Hardware...|2020-04-06| 45.02|     13.14|  98|      8.67|  97|      5.13|  96|    5.42| 91|
# |  OSPN|Computer Sftwr-Se...|2020-04-06|  17.6|     15.49|  98|     11.43|  98|      7.99|  97|    8.04| 93|
# |  OPRX|Computer Sftwr-Me...|2020-04-06|  8.66|     14.85|  98|      3.93|  95|     -1.69|  92|  -27.25| 56|
# |  QLYS|Computer Sftwr-Se...|2020-04-06| 91.13|     15.54|  98|     11.96|  98|     10.32|  98|    9.61| 94|
# |  AEYE|Computer Sftwr-En...|2020-04-06|   4.1|     12.33|  98|       4.8|  96|      -1.1|  93|  -24.89| 60|
# |  BAND|Computer Sftwr-En...|2020-04-06| 72.13|     12.07|  98|      9.16|  97|      8.14|  97|     4.7| 91|
# |  ANET| Computer-Networking|2020-04-06| 207.6|      8.82|  97|      3.26|  95|      1.96|  94|  -12.06| 77|
# |  SIMO|Computer-Data Sto...|2020-04-06|  41.0|      9.92|  97|      2.38|  94|     -3.52|  90|    -6.1| 84|
# |  ORCL|Computer Sftwr-Da...|2020-04-06| 51.49|       8.7|  97|      4.31|  96|      1.62|  94|   -6.82| 83|
# |  TDOC|Computer Sftwr-Me...|2020-04-06|150.13|     10.47|  97|      19.4|  99|     31.84|  99|  108.78| 99|
# |  FSLY|Computer Sftwr-En...|2020-04-06| 20.58|      8.37|  96|      5.16|  96|      2.32|  95|    null|  0|
# |  CDNS|Computer Sftwr-De...|2020-04-06| 69.42|      7.25|  96|      3.09|  95|      1.24|  94|    0.55| 88|
# |    ZM|Computer Sftwr-En...|2020-04-06|122.94|      7.54|  96|     17.68|  99|     31.13|  99|    null|  0|
# |  VEEV|Computer Sftwr-Me...|2020-04-06|156.81|      7.22|  96|      6.11|  96|      6.41|  96|    6.63| 92|
# |  FIVN|Computer Sftwr-En...|2020-04-06| 77.97|      8.34|  96|      7.76|  97|      8.91|  97|   35.07| 98|
# |  FTNT|Computer Sftwr-Se...|2020-04-06|107.88|      8.42|  96|      2.92|  95|      0.49|  94|   19.49| 96|
# |  AKAM|Computer Sftwr-En...|2020-04-06| 97.79|      7.91|  96|      6.11|  96|      6.87|  97|   16.69| 95|
# |  DOCU|Computer Sftwr-En...|2020-04-06| 90.15|       7.3|  96|       8.6|  97|     11.06|  98|   45.12| 98|
# |  CHKP|Computer Sftwr-Se...|2020-04-06|103.58|      5.05|  95|      0.43|  93|     -2.21|  92|  -10.67| 78|
# |  CSCO| Computer-Networking|2020-04-06| 41.43|      4.41|  94|     -1.26|  92|     -4.81|  89|  -18.14| 69|
# |   NET|Computer Sftwr-En...|2020-04-06| 23.64|      3.82|  94|     12.07|  98|     18.04|  99|    null|  0|
# |   BOX|Computer Sftwr-Da...|2020-04-06| 15.34|       4.5|  94|      2.74|  94|     -0.44|  93|  -13.14| 76|
# |  NTCT|Computer Sftwr-Da...|2020-04-06| 26.14|      4.27|  94|      1.42|  94|       1.6|  94|    4.98| 91|
# |  GRVY|Computer Sftwr-Ga...|2020-04-06| 28.92|      3.95|  94|     -0.49|  93|     -6.03|  88|  -28.23| 54|
# |  JKHY|Computer Sftwr-Fi...|2020-04-06|167.34|      3.65|  94|      3.17|  95|      5.25|  96|   16.72| 95|
# |  SMAR|Computer Sftwr-En...|2020-04-06| 44.52|      3.03|  93|     -0.53|  92|      -1.7|  92|    2.47| 90|
# +------+--------------------+----------+------+----------+----+----------+----+----------+----+--------+---+
# only showing top 30 rows

# %%
[c for c in dfUniverse.columns if c.find("Vol") >= 0]
#list(dfUniverse.columns)
cols = ["Symbol", 'Industry_Name', 'Comp_Rating', 'EPS_Rating', 'Ind_Group_Rank', 'Ind_Group_RS', 'Annual_Sales_mil', "EG0", "EG1", "EG2", "EG3", "EG4", "EG5", "SG0", "SG1", "SG2", "SG3", "SG4", "SG5"]
dfUniverse[(dfUniverse.Symbol == 'TGT')][cols]

#dfUniverse[(dfUniverse.Symbol == 'STLD')].to_dict(orient='list')
# Out:
# ['50_Day_Avg_Vol_1000s',
#  '50_Day_Avg_Dollar_Vol_1000s',
#  'Volume_1000s',
#  'Dollar_Volume_mil',
#  'Dollar_Volume_Sales']
#      Symbol             Industry_Name  Comp_Rating  EPS_Rating  \
# 2962    TGT  Retail-Major Disc Chains         85.0        84.0
#
#       Ind_Group_Rank Ind_Group_RS  Annual_Sales_mil  EG0    EG1   EG2    EG3  \
# 2962              39           A-           93561.0  8.0  525.0  58.0  105.0
#
#        EG4   EG5   SG0   SG1   SG2   SG3   SG4   SG5
# 2962  85.6 -61.4  10.0  22.8  21.2  21.2  24.8  11.0

# %%
dfUniverse[cond].Symbol[:50]
# Out:
# 63        AEM
# 146      AMBA
# 151       AMD
# 182        AN
# 200      APAM
# 267      ATKR
# 294      AVNT
# 342      BBDC
# 350        BC
# 352       BCC
# 720      COIN
# 764       CRK
# 907      DIOD
# 936      DOCS
# 947        DQ
# 988      ECHO
# 1014     ELAN
# 1019      ELY
# 1026     ENPH
# 1101     EXPI
# 1110     FANG
# 1115       FB
# 1192      FND
# 1196      FNV
# 1316     GLOB
# 1340     GOOG
# 1341    GOOGL
# 1435     HIMX
# 1439      HLI
# 1581     INMD
# 1702     KLIC
# 1740      LAD
# 1787     LGND
# 1828      LPX
# 1838     LSTR
# 1859      LZB
# 1969     MNSO
# 1994     MPWR
# 2007     MRVI
# 2239     OLPX
# 2331      PCH
# 2362      PFE
# 2431     POWI
# 2476     PUBM
# 2482      PWP
# 2492     QCOM
# 2524     RCII
# 2544     REGN
# 2669     SCCO
# 2671     SCHN
# Name: Symbol, dtype: object

# %%
dfUniverse[(dfUniverse.Symbol == 'ABCL')].to_dict(orient='list')
# Out:
# {'Order': [15],
#  'Symbol': ['ABCL'],
#  'Name': ['Abcellera Biologics Inc'],
#  'Industry_Name': ['Medical-Biomed/Biotech'],
#  'Ind_Group_Rank': [42],
#  'Sector': ['MEDICAL'],
#  'Shares_1000s': [278703],
#  'Shares_in_Float_1000s': [153286],
#  'Market_Cap_mil': [4914.9],
#  'Funds_Perc': [31.0],
#  'Funds_Perc_Increase': [26.7],
#  'Mgmt_Perc': [44.0],
#  'Number_of_Funds': [76.0],
#  'Inst_Ownership_Lss_Median': [0.0],
#  'Sponsor_Rating': ['B'],
#  'Enterprise_Val_mil': [4792.6],
#  'EPS_Rating': [29.0],
#  'RS_Rating': [19.0],
#  'SMR_Rating': ['B'],
#  'AD_Rating': ['B'],
#  'Comp_Rating': [39.0],
#  'Ind_Group_RS': ['A-'],
#  'EPS_Lst_Rptd': ['2021-08-12'],
#  'EPS_Due_Date': ['2021-10-28'],
#  'EPS_Perc_Chg_Last_Qtr': [nan],
#  'EG0': [-133.0],
#  'EPS_Perc_Chg_1_Q_Ago': [nan],
#  'EG1': [3800.0],
#  'EPS_Perc_Chg_2_Q_Ago': [nan],
#  'EG2': [4500.0],
#  'EPS_Perc_Chg_3_Q_Ago': [nan],
#  'EG3': [-200.0],
#  'EPS_Accel_3_Qtrs': [0],
#  'EPS_Trailing_4_Qtrs': [0.79],
#  'EPS_Perc_Growth_5_Yr_Pct_Rnk': [nan],
#  'EPS_Est_Next_Yr_Perc': [nan],
#  'EPS_Est_Cur_Yr_Perc': [-16.0],
#  'EPS_Est_Cur_Qtr_Perc': [-200.0],
#  'EPS_Surprise': [-112.5],
#  'Sustainable_Growth_Perc': [28.0],
#  'Earnings_Stability': [nan],
#  'Avg_EPS_Perc_Chg_2Q': [nan],
#  'Avg_EPS_Perc_Chg_3Q': [nan],
#  'Avg_EPS_Perc_Chg_4Q': [nan],
#  'Avg_EPS_Perc_Chg_5Q': [nan],
#  'Avg_EPS_Perc_Chg_6Q': [nan],
#  'EPS_Perc_Chg_Lst_Yr': [4600.0],
#  'EPS_Perc_Chg_1_Yr_Ago': [-200.0],
#  'EPS_Perc_Growth_1_Yr': [nan],
#  'EPS_Perc_Growth_3_Yr': [nan],
#  'EPS_Perc_Growth_5_Yr': [nan],
#  'Fiscal_EPS_Lst_Yr': [0.45],
#  'Fiscal_EPS_1_Yr_Ago': [-0.01],
#  'Fiscal_EPS_2_Yrs_Ago': [0.01],
#  'Fiscal_EPS_3_Yrs_Ago': [nan],
#  'Fiscal_EPS_4_Yrs_Ago': [nan],
#  'Fiscal_EPS_5_Yrs_Ago': [nan],
#  'Fiscal_EPS_6_Yrs_Ago': [nan],
#  'SG0': [146.0],
#  'Avg_Sales_Perc_Chg_2Q': [2198.4],
#  'Avg_Sales_Perc_Chg_3Q': [3598.0],
#  'Avg_Sales_Perc_Chg_4Q': [2741.3],
#  'Avg_Sales_Perc_Chg_5Q': [2263.6],
#  'Avg_Sales_Perc_Chg_6Q': [1901.0],
#  'Sales_Perc_Chg_Lst_Yr': [1908.0],
#  'Sales_Accel_2_Qtrs': [0],
#  'Sales_Accel_3_Qtrs': [0],
#  'Sales_Growth_3_Yr': [459.0],
#  'Sales_Growth_5_Yr': [nan],
#  'Annual_Sales_mil': [233.2],
#  'Current_Price': [17.62],
#  '50_Day_Avg_Vol_1000s': [2556.0],
#  '50_Day_Avg_Dollar_Vol_1000s': [51222],
#  'Volume_1000s': [6386],
#  'Timeliness_Rating': ['C'],
#  'Avg_True_Range': [1.3],
#  'Beta': [0.48],
#  'Alpha': [0.92],
#  'RS_6_Month_Rating': [25.0],
#  'RS_3_Month_Rating': [95.0],
#  'RS_Line_New_Low': [0.0],
#  'RS_Line_New_High': [0.0],
#  'Perc_Off_High': [-70.97],
#  'Yield_Perc': [0.0],
#  'Pre_tax_Margins': [67.7],
#  'AT_Margin_Accel': [0],
#  'PE_Lss_5_Yr_Avg': [0],
#  'LT_Debt_to_Working_Cap': [0.0],
#  'PE_Ratio_Rank_in_Grp': [46.0],
#  'PE_Percent_Rank': [64.0],
#  'Est_PE': [53.0],
#  'PE_vs_S&P_500_PE_Perc': [105.7],
#  'AT_Margin': [-0.6],
#  'Avg_AT_Margin_2Q': [28.6],
#  'Avg_AT_Margin_3Q': [37.8],
#  'Avg_AT_Margin_4Q': [21.2],
#  'Avg_AT_Margin_5Q': [28.9],
#  'Avg_AT_Margin_6Q': [16.6],
#  'PE': [25.0],
#  'ROE': [28.3],
#  'ROE_5_Yr_Avg': [-55.8],
#  'Debt_Perc': [0.3],
#  'Current_Ratio': [12.39],
#  'Price_to_Sales': [10.98],
#  'Price_to_Book': [6.49],
#  'Price_to_CF': [237.68],
#  'Exchange': ['NASDAQ'],
#  'ADR': [0],
#  'IPO_Date': ['2020-12-11'],
#  'Company_Description': ['CANADIAN PROVIDER OF DRUG DISCOVERY PLATFORM DESIGNED TO DEV ELOP NEXT-GENERATION ANTIBODY THERAPIES.'],
#  'Incorp_Date': [2012.0],
#  'IBD_Article_2_Yrs': [0],
#  'EG4': [nan],
#  'EG5': [nan],
#  'SG1': [4250.8],
#  'SG2': [6397.2],
#  'SG3': [171.2],
#  'SG4': [352.8],
#  'SG5': [88.0],
#  'Dollar_Volume_mil': [112.52],
#  'Dollar_Volume_Sales': [0.48]}
